# %%
from prepare_data import augment_audio
import pandas as pd

# %%
X_train = pd.read_csv("csvki/asv2019_inthewild_dataset.csv")

# %%
singel_data = X_train.iloc[567]

# %%
singel_data
# Out:
# Unnamed: 0                                                   913
# filepath       C:\Users\izaol\Downloads\archive (1)\release_i...
# chunk_index                                                    2
# chunk_start                                                  4.0
# chunk_end                                                    6.0
# label                                                          0
# Name: 567, dtype: object

# %%
augment_audio(singel_data['filepath'], "noise", factor=0.0125)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
augment_audio(singel_data['filepath'], "speed", factor=1.025)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
