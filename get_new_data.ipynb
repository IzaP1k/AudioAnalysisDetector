# %%
from ASV_dl_func import prepare_dirs_dataset
import os

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
from omegaconf import OmegaConf

config = OmegaConf.load("config.yaml")

dir_path = config.paths.in_the_wild_dir

# %%
print(os.listdir(dir_path))

# %%
dfs = prepare_dirs_dataset(dir_path)

# %%
dfs[1].to_csv("in_the_wild.csv")

# %%
dfs[0].to_csv("test_in_the_wild.csv")

# %%
dfs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dfs
#
# NameError: name 'dfs' is not defined
